# %%
import pickle

with open('../data/Asl-pose-normalized/0a0px34qrq.pkl', 'rb') as f:
    data = pickle.load(f)
data.keys()
# Out:
# dict_keys(['body', 'left', 'right', 'face_all'])

# %%
data['body'][0].shape
# Out:
# (9, 3)

# %%
data['left'][0].shape
# Out:
# (21, 3)

# %%
data['right'][0].shape
# Out:
# (21, 3)

# %%
data['face_all'][0].shape
# Out:
# (18, 3)
